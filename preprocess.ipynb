# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: ramp-workflow in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: osfclient in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.0.5)
# Requirement already satisfied: numpy==1.25.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.25.2)
# Requirement already satisfied: matplotlib==3.7.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.7.2)
# Requirement already satisfied: pandas==2.0.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: scipy==1.11.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.11.1)
# Requirement already satisfied: lightgbm in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (4.6.0)
# Requirement already satisfied: numba in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.62.1)
# Collecting imblearn (from -r requirements.txt (line 13))
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.13.2)
# Requirement already satisfied: jupyterlab in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (4.4.10)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (1.5.2)
# Requirement already satisfied: flake8 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (7.3.0)
# Requirement already satisfied: black in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (25.11.0)
# Requirement already satisfied: scanpy in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (1.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (12.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.10/site-packages (from matplotlib==3.7.2->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: joblib in ./.venv/lib/python3.10/site-packages (from ramp-workflow->-r requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.10/site-packages (from ramp-workflow->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: click in ./.venv/lib/python3.10/site-packages (from ramp-workflow->-r requirements.txt (line 2)) (8.3.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from osfclient->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (from osfclient->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: six in ./.venv/lib/python3.10/site-packages (from osfclient->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in ./.venv/lib/python3.10/site-packages (from numba->-r requirements.txt (line 11)) (0.45.1)
# Collecting imbalanced-learn (from imblearn->-r requirements.txt (line 13))
#   Using cached imbalanced_learn-0.14.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (7.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (3.1.6)
# Requirement already satisfied: jupyter-core in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (80.9.0)
# Requirement already satisfied: tomli>=1.2.2 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (2.3.0)
# Requirement already satisfied: tornado>=6.2.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (6.5.2)
# Requirement already satisfied: traitlets in ./.venv/lib/python3.10/site-packages (from jupyterlab->-r requirements.txt (line 17)) (5.14.3)
# Requirement already satisfied: anyio in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (4.11.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 17)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 17)) (4.25.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 19)) (3.6.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from flake8->-r requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in ./.venv/lib/python3.10/site-packages (from flake8->-r requirements.txt (line 23)) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in ./.venv/lib/python3.10/site-packages (from flake8->-r requirements.txt (line 23)) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./.venv/lib/python3.10/site-packages (from black->-r requirements.txt (line 24)) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./.venv/lib/python3.10/site-packages (from black->-r requirements.txt (line 24)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib/python3.10/site-packages (from black->-r requirements.txt (line 24)) (4.5.0)
# Requirement already satisfied: pytokens>=0.3.0 in ./.venv/lib/python3.10/site-packages (from black->-r requirements.txt (line 24)) (0.3.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in ./.venv/lib/python3.10/site-packages (from black->-r requirements.txt (line 24)) (4.15.0)
# Requirement already satisfied: anndata>=0.8 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (0.11.4)
# Requirement already satisfied: h5py>=3.7 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (3.15.1)
# Requirement already satisfied: legacy-api-wrap>=1.4 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (1.5)
# Requirement already satisfied: natsort in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (3.4.2)
# Requirement already satisfied: patsy!=1.0.0 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (0.5.13)
# Requirement already satisfied: session-info2 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (0.2.3)
# Requirement already satisfied: statsmodels>=0.13 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (0.14.5)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in ./.venv/lib/python3.10/site-packages (from scanpy->-r requirements.txt (line 27)) (0.5.7)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in ./.venv/lib/python3.10/site-packages (from anndata>=0.8->scanpy->-r requirements.txt (line 27)) (1.12.0)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.10/site-packages (from anndata>=0.8->scanpy->-r requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (7.1.3)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (2.19.2)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 17)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 17)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 17)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 17)) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.1.0)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (6.3.0)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->osfclient->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests->osfclient->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in ./.venv/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (2.8)
# INFO: pip is looking at multiple versions of imbalanced-learn to determine which version is compatible with other requirements. This could take a while.
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn->imblearn->-r requirements.txt (line 13))
#   Downloading sklearn_compat-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab->-r requirements.txt (line 17)) (0.2.3)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.4-py3-none-any.whl (19 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn, imblearn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [imblearn]1/3 [imbalanced-learn]
# Successfully installed imbalanced-learn-0.13.0 imblearn-0.0 sklearn-compat-0.1.4

# %%
# !python download_data.py
# Out:
# /home/valitar/Documents/M2DS/DataCamp/scmark-classification-etoiles/data directory is not empty. Please empty it or select another destination for LOCAL_DATA if you wish to proceed

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from problem import get_train_data, get_test_data
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1000, 13551), (1000,), (500, 13551), (500,))

# %% [markdown]
# ## Labels

# %%
lab_df = pd.DataFrame({'label': y_train})
lab_df.value_counts(normalize=True)
# Out:
# label
# T_cells_CD8+    0.342
# T_cells_CD4+    0.336
# Cancer_cells    0.237
# NK_cells        0.085
# Name: proportion, dtype: float64

# %%
lab_df.label.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Oversampling

# %%
# ### Oversampling
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
ros = RandomOverSampler(random_state=42)
smote = SMOTE(random_state=42)
adasyn = ADASYN(random_state=42)

X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
# X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
# X_resampled, y_resampled = adasyn.fit_resample(X_train, y_train)
X_resampled.shape, y_resampled.shape
# Out:
# ((1368, 13551), (1368,))

# %%
lab_df_resampled = pd.DataFrame({'label': y_resampled})
lab_df_resampled.label.hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Tests sur PCA selon n_components

# %% [markdown]
# ## resampled

# %%
from sklearn.decomposition import PCA
var = []
for k in range(2, 50):
    pca = PCA(n_components=k)
    X_pca = pca.fit_transform(X_resampled)
    # afficher la variance expliquée
    explained_variance = pca.explained_variance_ratio_
    var.append(explained_variance.sum())

# %%
# afficher avec matplotlib
plt.plot(range(2, 50), var)
plt.xlabel('Nombre de composantes principales')
plt.ylabel('Variance expliquée')
plt.title('Variance expliquée en fonction du nombre de composantes principales')
plt.show()

# %% [markdown]
# ## sans resample

# %%
from sklearn.decomposition import PCA
var = []
for k in range(2, 50):
    pca = PCA(n_components=k)
    X_pca = pca.fit_transform(X_train)
    # afficher la variance expliquée
    explained_variance = pca.explained_variance_ratio_
    var.append(explained_variance.sum())

# %%
# afficher avec matplotlib
plt.plot(range(2, 50), var)
plt.xlabel('Nombre de composantes principales')
plt.ylabel('Variance expliquée')
plt.title('Variance expliquée en fonction du nombre de composantes principales')
plt.show()

# %%
# on modifie X_train pour passer de csr_matrix à DataFrame
X_train = pd.DataFrame(X_train.toarray())
X_test = pd.DataFrame(X_test.toarray())

# %%
# pour chaque gène la variance de leur expression sur chaque cellule

gene_variances = X_train.var(axis=0)
# trier les gènes par variance décroissante
sorted_genes = np.argsort(gene_variances)[::-1]
# sélectionner les 50 gènes les plus variables
top_genes = sorted_genes[:50]
# réduire X_train et X_test aux 50 gènes les plus variables
X_train_top = X_train.iloc[:, top_genes]
X_test_top = X_test.iloc[:, top_genes]

# %%
# afficher les gènes dans un graphe en fonction de leur variance de leur expression
plt.figure(figsize=(10, 6))
plt.bar(range(len(gene_variances)), sorted(gene_variances, reverse=True))
plt.xlabel('Gènes triés par variance décroissante')
plt.ylabel('Variance de l\'expression')
plt.title('Variance de l\'expression des gènes')
plt.show()

# %%
# meme chose mais sur les 5000 gènes les plus variables
plt.figure(figsize=(10, 6))
plt.bar(range(len(X_train_top.var(axis=0))), sorted(X_train_top.var(axis=0), reverse=True))
plt.xlabel('Gènes triés par variance décroissante (top 50)')
plt.ylabel('Variance de l\'expression')
plt.title('Variance de l\'expression des 50 gènes les plus variables')
plt.show()

# %% [markdown]
# ## visualisation

# %%
from matplotlib.colors import ListedColormap

# Créer un mapping des catégories à des indices numériques
categories = np.unique(y_resampled)
category_to_color = {category: idx for idx, category in enumerate(categories)}

# Mapper les catégories de y_resampled à des indices numériques
y_colors = np.array([category_to_color[label] for label in y_resampled])

# Définir une palette de couleurs
cmap = ListedColormap(plt.cm.viridis(np.linspace(0, 1, len(categories))))

# Tracer le graphique avec les couleurs mappées
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_colors, cmap=cmap, alpha=0.5)
plt.xlabel('Composante principale 1')
plt.ylabel('Composante principale 2')
plt.title('Projection des données dans le plan des 2 premières composantes principales')
plt.colorbar(scatter, ticks=range(len(categories)), label='Catégorie').ax.set_yticklabels(categories)
plt.show()

# %%
# on souhaite voir les genes les plus importants dans les composantes principales en affichant des barplots
# on commence par passer les X_train de csr_matrix à DataFrame
X_train = pd.DataFrame(X_train.toarray(), columns=[f'gene_{i}' for i in range(X_train.shape[1])])
pca = PCA(n_components=20)
X_pca = pca.fit_transform(X_train)
components = pca.components_
genes = X_train.columns
for i in range(3):  # afficher les 3 premières composantes
    plt.figure(figsize=(10, 6))
    plt.bar(genes, components[i])
    plt.xlabel('Gènes')
    plt.ylabel('Poids')
    plt.title(f'Composante principale {i+1}')
    plt.xticks(rotation=90)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 14
#      12 plt.ylabel('Poids')
#      13 plt.title(f'Composante principale {i+1}')
# ---> 14 plt.xticks(rotation=90)
#      15 plt.show()
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/pyplot.py:1889, in xticks(ticks, labels, minor, **kwargs)
#    1886     locs = ax.set_xticks(ticks, minor=minor)
#    1888 if labels is None:
# -> 1889     labels = ax.get_xticklabels(minor=minor)
#    1890     for l in labels:
#    1891         l._internal_update(kwargs)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axis.py:1456, in Axis.get_ticklabels(self, minor, which)
#    1454 if minor:
#    1455     return self.get_minorticklabels()
# -> 1456 return self.get_majorticklabels()
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axis.py:1413, in Axis.get_majorticklabels(self)
#    1411 def get_majorticklabels(self):
#    1412     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1413     self._update_ticks()
#    1414     ticks = self.get_major_ticks()
#    1415     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axis.py:1264, in Axis._update_ticks(self)
#    1262 major_locs = self.get_majorticklocs()
#    1263 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1264 major_ticks = self.get_major_ticks(len(major_locs))
#    1265 self.major.formatter.set_locs(major_locs)
#    1266 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axis.py:1602, in Axis.get_major_ticks(self, numticks)
#    1598     numticks = len(self.get_majorticklocs())
#    1600 while len(self.majorTicks) < numticks:
#    1601     # Update the new tick label properties from the old.
# -> 1602     tick = self._get_tick(major=True)
#    1603     self.majorTicks.append(tick)
#    1604     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axis.py:1551, in Axis._get_tick(self, major)
#    1547     raise NotImplementedError(
#    1548         f"The Axis subclass {self.__class__.__name__} must define "
#    1549         "_tick_class or reimplement _get_tick()")
#    1550 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1551 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axis.py:417, in XTick.__init__(self, *args, **kwargs)
#     416 def __init__(self, *args, **kwargs):
# --> 417     super().__init__(*args, **kwargs)
#     418     # x in data coords, y in axes coords
#     419     ax = self.axes
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/axis.py:174, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     166 self.gridline = mlines.Line2D(
#     167     [], [],
#     168     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     169     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     170     **grid_kw,
#     171 )
#     172 self.gridline.get_path()._interpolation_steps = \
#     173     GRIDLINE_INTERPOLATION_STEPS
# --> 174 self.label1 = mtext.Text(
#     175     np.nan, np.nan,
#     176     fontsize=labelsize, color=labelcolor, visible=label1On,
#     177     rotation=self._labelrotation[1])
#     178 self.label2 = mtext.Text(
#     179     np.nan, np.nan,
#     180     fontsize=labelsize, color=labelcolor, visible=label2On,
#     181     rotation=self._labelrotation[1])
#     183 self._apply_tickdir(tickdir)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/text.py:168, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, **kwargs)
#     166 self._x, self._y = x, y
#     167 self._text = ''
# --> 168 self._reset_visual_defaults(
#     169     text=text,
#     170     color=color,
#     171     fontproperties=fontproperties,
#     172     usetex=usetex,
#     173     parse_math=parse_math,
#     174     wrap=wrap,
#     175     verticalalignment=verticalalignment,
#     176     horizontalalignment=horizontalalignment,
#     177     multialignment=multialignment,
#     178     rotation=rotation,
#     179     transform_rotates_text=transform_rotates_text,
#     180     linespacing=linespacing,
#     181     rotation_mode=rotation_mode,
#     182 )
#     183 self.update(kwargs)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/text.py:218, in Text._reset_visual_defaults(self, text, color, fontproperties, usetex, parse_math, wrap, verticalalignment, horizontalalignment, multialignment, rotation, transform_rotates_text, linespacing, rotation_mode)
#     216 if linespacing is None:
#     217     linespacing = 1.2  # Maybe use rcParam later.
# --> 218 self.set_linespacing(linespacing)
#     219 self.set_rotation_mode(rotation_mode)
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/text.py:1040, in Text.set_linespacing(self, spacing)
#    1030 def set_linespacing(self, spacing):
#    1031     """
#    1032     Set the line spacing as a multiple of the font size.
#    1033
#    (...)
#    1038     spacing : float (multiple of font size)
#    1039     """
# -> 1040     _api.check_isinstance(Real, spacing=spacing)
#    1041     self._linespacing = spacing
#    1042     self.stale = True
#
# File ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/matplotlib/_api/__init__.py:87, in check_isinstance(_types, **kwargs)
#      82 def type_name(tp):
#      83     return ("None" if tp is none_type
#      84             else tp.__qualname__ if tp.__module__ == "builtins"
#      85             else f"{tp.__module__}.{tp.__qualname__}")
# ---> 87 for k, v in kwargs.items():
#      88     if not isinstance(v, types):
#      89         names = [*map(type_name, types)]
#
# KeyboardInterrupt:

# %% [markdown]
# # On essaie sur l'entraînement

# %%
from sklearn.metrics import balanced_accuracy_score

# %%
# this custom class is used by the challenge and calls 
# balanced_accuracy_score(y_true, y_pred, adjusted=False)
# under the hood
from problem import BalancedAccuracy

# %%
def preprocess_X(X):
    X = X.toarray()
    return X / X.sum(axis=1)[:, np.newaxis]

X_train_norm = preprocess_X(X_train) # modifier ici
# sanity check
np.allclose(X_train_norm.sum(axis=1), np.ones(X_train_norm.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_111653/3705449311.py in ?()
#       1 def preprocess_X(X):
#       2     X = X.toarray()
#       3     return X / X.sum(axis=1)[:, np.newaxis]
#       4
# ----> 5 X_train_norm = preprocess_X(X_train_top) # modifier ici
#       6 # sanity check
#       7 np.allclose(X_train_norm.sum(axis=1), np.ones(X_train_norm.shape[0]))
#
# /tmp/ipykernel_111653/3705449311.py in ?(X)
#       1 def preprocess_X(X):
# ----> 2     X = X.toarray()
#       3     return X / X.sum(axis=1)[:, np.newaxis]
#
# ~/Documents/M2DS/DataCamp/scmark-classification-etoiles/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'toarray'

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier


pipe = Pipeline(
    [
        ("Scaler", StandardScaler(with_mean=True, with_std=True)),
        ("PCA with 50 components", PCA(n_components=20)),
        (
            "Random Forest Classifier",
            RandomForestClassifier(
                max_depth=5, n_estimators=100, max_features=3
            ),
        ),
    ]
)

pipe
# Out:
# Pipeline(steps=[('Scaler', StandardScaler()),
#                 ('PCA with 50 components', PCA(n_components=20)),
#                 ('Random Forest Classifier',
#                  RandomForestClassifier(max_depth=5, max_features=3))])

# %%
# fit on train
pipe.fit(X_train_norm, y_train)
y_tr_pred = pipe.predict(X_train_norm)

# predict on test
X_test_norm = preprocess_X(X_test)
y_te_pred = pipe.predict(X_test_norm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # fit on train
# ----> 2 pipe.fit(X_train_norm, y_train)
#       3 y_tr_pred = pipe.predict(X_train_norm)
#       5 # predict on test
#
# NameError: name 'X_train_norm' is not defined

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# compute balanced accuracy and confusion matrix
print(f"Train balanced accuracy : {balanced_accuracy_score(y_train, y_tr_pred):.3f}")
print(f"Test balanced accuracy : {balanced_accuracy_score(y_test, y_te_pred):.3f}")
cm = confusion_matrix(y_test, y_te_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipe.classes_, )
disp.plot()
plt.title("Confusion matrix on test set");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2 from sklearn.metrics import ConfusionMatrixDisplay
#       4 # compute balanced accuracy and confusion matrix
# ----> 5 print(f"Train balanced accuracy : {balanced_accuracy_score(y_train, y_tr_pred):.3f}")
#       6 print(f"Test balanced accuracy : {balanced_accuracy_score(y_test, y_te_pred):.3f}")
#       7 cm = confusion_matrix(y_test, y_te_pred)
#
# NameError: name 'y_tr_pred' is not defined
